# %% [markdown]
# ## Credit card fraud detection

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
cr_data = pd.read_csv('creditcard.csv')

# %%
cr_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
cr_data.shape
# Out:
# (284807, 31)

# %%
cr_data.info() # we can check if there is any null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
cr_data.isnull().count() # So from the result it is clear that there is no missing values
# Out:
# Time      284807
# V1        284807
# V2        284807
# V3        284807
# V4        284807
# V5        284807
# V6        284807
# V7        284807
# V8        284807
# V9        284807
# V10       284807
# V11       284807
# V12       284807
# V13       284807
# V14       284807
# V15       284807
# V16       284807
# V17       284807
# V18       284807
# V19       284807
# V20       284807
# V21       284807
# V22       284807
# V23       284807
# V24       284807
# V25       284807
# V26       284807
# V27       284807
# V28       284807
# Amount    284807
# Class     284807
# dtype: int64

# %%
# Now we check no of fraud detections
cr_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# # 0 --> Normal transaction
# # 1 --> Fraud transaction

# %%
### This is a highly unbalanced data

# %%
Norm_tr = cr_data[cr_data.Class == 0]
Fraud_tr = cr_data[cr_data.Class == 1]

# %%
# statistical data
cr_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# now we can take the mean of both categories
cr_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ### Dealing with unbalanced data using undersampling

# %%
# we have 492 fraud transactions. so we take the same no of normal transaction samples
legit_sample = Norm_tr.sample(n=492)

# %%
# Now we have to concat two datasets
new_dt = pd.concat([legit_sample,Fraud_tr],axis=0)

# %%
new_dt.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 139293   83091.0  0.109574 -2.150589  0.508889  0.710086 -1.730478 -0.172782
# 38981    39638.0  1.279970 -0.266108 -0.992069 -0.285321  1.883019  3.657542
# 259204  159012.0 -1.118151  0.682618  2.028488 -0.354851 -0.620413  0.733253
# 214800  139826.0  2.062894 -0.024915 -1.053621  0.415011 -0.119025 -1.211603
# 267682  162874.0 -0.463920  0.923648 -0.983204 -1.224668  1.381463 -1.166615
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 139293  0.128049 -0.113379  1.086210  ...  0.115750 -0.685520 -0.426385
# 38981  -0.715670  0.900671  0.496412  ... -0.142442 -0.316956 -0.123535
# 259204 -0.747804  0.955963  0.886134  ...  0.096444  0.365158 -0.362087
# 214800  0.206113 -0.353786  0.492147  ... -0.285279 -0.670769  0.337892
# 267682  1.472844 -0.234363 -0.381720  ...  0.255403  0.908997 -0.183222
#
# ...

# %%
new_dt['Class'].value_counts()# Now we have a  uniformly distributed dataset
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_dt.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95193.971545  0.138440  0.071021  0.090073  0.115690  0.041518
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.020148  0.003446  0.062206  0.081474  ... -0.027608  0.027601
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.059462 -0.021935 -0.006386  0.029697 -0.019263 -0.027110 -0.014140
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       68.132256
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ### Splitting the data

# %%
X = new_dt.drop(columns = 'Class', axis = 1)

# %%
Y = new_dt['Class']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,stratify = Y,random_state =2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (787, 30)
# (197, 30)

# %% [markdown]
# ## building the model

# %%
model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# C:\Users\TUFF\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# ### Model Evaluation

# %%
### Accuracy Score 
X_train_predict = model.predict(X_train)
train_data_accuracy = accuracy_score(X_train_predict,Y_train)
print("Accuracy of training data:",train_data_accuracy )
# Out:
# Accuracy of training data: 0.9504447268106735

# %%
### Accuracy score
X_test_predict =  model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_predict,Y_test)
print("Accuracy of training data:",test_data_accuracy )
# Out:
# Accuracy of training data: 0.9187817258883249
